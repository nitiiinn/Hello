# %%
paragraph="""Formula 1, often referred to as F1, is the highest class of international single-seater racing and is widely considered the pinnacle of motorsport due to its unmatched combination of speed, technology, and global spectacle. Governing bodies, teams, and engineers collaborate to push the boundaries of automotive innovation, developing cars capable of exceeding 350 km/h while maintaining precision through some of the most challenging corners and circuits in the world. Each season consists of a series of Grand Prix races held across various countries, turning the championship into a worldwide tour that showcases diverse cultures and racing traditions. The sport features 10 teams and 20 elite drivers who undergo rigorous physical and mental training to withstand intense G-force, split-second decision-making, and fierce competition. Strategy plays a crucial role, with pit stops, tire choices, aerodynamics, and real-time data analysis contributing to every race’s outcome. The roar of hybrid power units, the complexity of cutting-edge electronics, and the artistry of aerodynamic design make every car a marvel of modern engineering. Beyond the track, F1 has evolved into a massive global entertainment industry, attracting millions of fans, generating significant economic impact, and inspiring advancements in everyday car technology, including safety systems and fuel-efficiency innovations. Its long history, legendary drivers like Michael Schumacher, Ayrton Senna, and Lewis Hamilton, and iconic teams such as Ferrari, McLaren, and Mercedes have cemented Formula 1’s reputation as not just a sport, but a thrilling fusion of science, skill, passion, and speed."""

# %%
import nltk
from nltk.corpus import stopwords
sentences=nltk.sent_tokenize(paragraph)

# %%
for i in range(len(sentences)):
    words=nltk.word_tokenize(sentences[i])
    words=[word for word in words if word not in set(stopwords.words('english'))]
    post_tag=nltk.pos_tag(words)
    print(post_tag)
# Out:
# [('Formula', 'NNP'), ('1', 'CD'), (',', ','), ('often', 'RB'), ('referred', 'VBD'), ('F1', 'NNP'), (',', ','), ('highest', 'JJS'), ('class', 'NN'), ('international', 'JJ'), ('single-seater', 'JJ'), ('racing', 'NN'), ('widely', 'RB'), ('considered', 'VBN'), ('pinnacle', 'NN'), ('motorsport', 'NN'), ('due', 'JJ'), ('unmatched', 'JJ'), ('combination', 'NN'), ('speed', 'NN'), (',', ','), ('technology', 'NN'), (',', ','), ('global', 'JJ'), ('spectacle', 'NN'), ('.', '.')]
# [('Governing', 'VBG'), ('bodies', 'NNS'), (',', ','), ('teams', 'NNS'), (',', ','), ('engineers', 'NNS'), ('collaborate', 'VBP'), ('push', 'JJ'), ('boundaries', 'NNS'), ('automotive', 'JJ'), ('innovation', 'NN'), (',', ','), ('developing', 'VBG'), ('cars', 'NNS'), ('capable', 'JJ'), ('exceeding', 'VBG'), ('350', 'CD'), ('km/h', 'JJ'), ('maintaining', 'VBG'), ('precision', 'NN'), ('challenging', 'VBG'), ('corners', 'NNS'), ('circuits', 'NNS'), ('world', 'NN'), ('.', '.')]
# [('Each', 'DT'), ('season', 'NN'), ('consists', 'VBZ'), ('series', 'NN'), ('Grand', 'NNP'), ('Prix', 'NNP'), ('races', 'VBZ'), ('held', 'VBN'), ('across', 'IN'), ('various', 'JJ'), ('countries', 'NNS'), (',', ','), ('turning', 'VBG'), ('championship', 'NN'), ('worldwide', 'IN'), ('tour', 'JJ'), ('showcases', 'NNS'), ('diverse', 'JJ'), ('cultures', 'NNS'), ('racing', 'VBG'), ('traditions', 'NNS'), ('.', '.')]
# [('The', 'DT'), ('sport', 'NN'), ('features', 'VBZ'), ('10', 'CD'), ('teams', 'NNS'), ('20', 'CD'), ('elite', 'JJ'), ('drivers', 'NNS'), ('undergo', 'VBP'), ('rigorous', 'JJ'), ('physical', 'JJ'), ('mental', 'NN'), ('training', 'NN'), ('withstand', 'NN'), ('intense', 'JJ'), ('G-force', 'NNP'), (',', ','), ('split-second', 'JJ'), ('decision-making', 'NN'), (',', ','), ('fierce', 'JJ'), ('competition', 'NN'), ('.', '.')]
# [('Strategy', 'NNP'), ('plays', 'VBZ'), ('crucial', 'JJ'), ('role', 'NN'), (',', ','), ('pit', 'NN'), ('stops', 'NNS'), (',', ','), ('tire', 'NN'), ('choices', 'NNS'), (',', ','), ('aerodynamics', 'NNS'), (',', ','), ('real-time', 'JJ'), ('data', 'NNS'), ('analysis', 'NN'), ('contributing', 'VBG'), ('every', 'DT'), ('race', 'NN'), ('’', 'VBZ'), ('outcome', 'NN'), ('.', '.')]
# [('The', 'DT'), ('roar', 'NN'), ('hybrid', 'JJ'), ('power', 'NN'), ('units', 'NNS'), (',', ','), ('complexity', 'NN'), ('cutting-edge', 'NN'), ('electronics', 'NNS'), (',', ','), ('artistry', 'NN'), ('aerodynamic', 'JJ'), ('design', 'NN'), ('make', 'VBP'), ('every', 'DT'), ('car', 'NN'), ('marvel', 'NN'), ('modern', 'JJ'), ('engineering', 'NN'), ('.', '.')]
# [('Beyond', 'NNP'), ('track', 'NN'), (',', ','), ('F1', 'NNP'), ('evolved', 'VBD'), ('massive', 'JJ'), ('global', 'JJ'), ('entertainment', 'NN'), ('industry', 'NN'), (',', ','), ('attracting', 'VBG'), ('millions', 'NNS'), ('fans', 'NNS'), (',', ','), ('generating', 'VBG'), ('significant', 'JJ'), ('economic', 'JJ'), ('impact', 'NN'), (',', ','), ('inspiring', 'VBG'), ('advancements', 'NNS'), ('everyday', 'JJ'), ('car', 'NN'), ('technology', 'NN'), (',', ','), ('including', 'VBG'), ('safety', 'NN'), ('systems', 'NNS'), ('fuel-efficiency', 'JJ'), ('innovations', 'NNS'), ('.', '.')]
# [('Its', 'PRP$'), ('long', 'JJ'), ('history', 'NN'), (',', ','), ('legendary', 'JJ'), ('drivers', 'NNS'), ('like', 'IN'), ('Michael', 'NNP'), ('Schumacher', 'NNP'), (',', ','), ('Ayrton', 'NNP'), ('Senna', 'NNP'), (',', ','), ('Lewis', 'NNP'), ('Hamilton', 'NNP'), (',', ','), ('iconic', 'JJ'), ('teams', 'NNS'), ('Ferrari', 'NNP'), (',', ','), ('McLaren', 'NNP'), (',', ','), ('Mercedes', 'NNP'), ('cemented', 'VBD'), ('Formula', 'NNP'), ('1', 'CD'), ('’', 'NNP'), ('reputation', 'NN'), ('sport', 'NN'), (',', ','), ('thrilling', 'VBG'), ('fusion', 'NN'), ('science', 'NN'), (',', ','), ('skill', 'NN'), (',', ','), ('passion', 'NN'), (',', ','), ('speed', 'NN'), ('.', '.')]

# %%
print(nltk.pos_tag("max verstappen will win the 2025 world driver championship".split()))
# Out:
# [('max', 'NN'), ('verstappen', 'NN'), ('will', 'MD'), ('win', 'VB'), ('the', 'DT'), ('2025', 'CD'), ('world', 'NN'), ('driver', 'NN'), ('championship', 'NN')]

# %% [markdown]
# ## NAMED ENTITY RECOGNITION

# %%
words=nltk.word_tokenize(paragraph)

# %%
tag_elements=nltk.pos_tag(words)

# %%
nltk.ne_chunk(tag_elements)
# Out:
# Tree('S', [('Formula', 'NNP'), ('1', 'CD'), (',', ','), ('often', 'RB'), ('referred', 'VBN'), ('to', 'TO'), ('as', 'IN'), Tree('GPE', [('F1', 'NNP')]), (',', ','), ('is', 'VBZ'), ('the', 'DT'), ('highest', 'JJS'), ('class', 'NN'), ('of', 'IN'), ('international', 'JJ'), ('single-seater', 'JJ'), ('racing', 'NN'), ('and', 'CC'), ('is', 'VBZ'), ('widely', 'RB'), ('considered', 'VBN'), ('the', 'DT'), ('pinnacle', 'NN'), ('of', 'IN'), ('motorsport', 'NN'), ('due', 'JJ'), ('to', 'TO'), ('its', 'PRP$'), ('unmatched', 'JJ'), ('combination', 'NN'), ('of', 'IN'), ('speed', 'NN'), (',', ','), ('technology', 'NN'), (',', ','), ('and', 'CC'), ('global', 'JJ'), ('spectacle', 'NN'), ('.', '.'), ('Governing', 'VBG'), ('bodies', 'NNS'), (',', ','), ('teams', 'NNS'), (',', ','), ('and', 'CC'), ('engineers', 'NNS'), ('collaborate', 'VBP'), ('to', 'TO'), ('push', 'VB'), ('the', 'DT'), ('boundaries', 'NNS'), ('of', 'IN'), ('automotive', 'JJ'), ('innovation', 'NN'), (',', ','), ('developing', 'VBG'), ('cars', 'NNS'), ('capable', 'JJ'), ('of', 'IN'), ('exceeding', 'VBG'), ('350', 'CD'), ('km/h', 'NNS'), ('while', 'IN'), ('maintaining', 'VBG'), ('precision', 'NN'), ('through', 'IN'), ('some', 'DT'), ('of', 'IN'), ('the', 'DT'), ('most', 'RBS'), ('challenging', 'JJ'), ('corners', 'NNS'), ('and', 'CC'), ('circuits', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('world', 'NN'), ('.', '.'), ('Each', 'DT'), ('season', 'NN'), ('consists', 'VBZ'), ('of', 'IN'), ('a', 'DT'), ('series', 'NN'), ('of', 'IN'), Tree('GPE', [('Grand', 'NNP')]), ('Prix', 'NNP'), ('races', 'VBZ'), ('held', 'VBN'), ('across', 'IN'), ('various', 'JJ'), ('countries', 'NNS'), (',', ','), ('turning', 'VBG'), ('the', 'DT'), ('championship', 'NN'), ('into', 'IN'), ('a', 'DT'), ('worldwide', 'JJ'), ('tour', 'NN'), ('that', 'WDT'), ('showcases', 'VBZ'), ('diverse', 'JJ'), ('cultures', 'NNS'), ('and', 'CC'), ('racing', 'VBG'), ('traditions', 'NNS'), ('.', '.'), ('The', 'DT'), ('sport', 'NN'), ('features', 'VBZ'), ('10', 'CD'), ('teams', 'NNS'), ('and', 'CC'), ('20', 'CD'), ('elite', 'JJ'), ('drivers', 'NNS'), ('who', 'WP'), ('undergo', 'VBP'), ('rigorous', 'JJ'), ('physical', 'JJ'), ('and', 'CC'), ('mental', 'JJ'), ('training', 'NN'), ('to', 'TO'), ('withstand', 'VB'), ('intense', 'JJ'), ('G-force', 'NNP'), (',', ','), ('split-second', 'JJ'), ('decision-making', 'NN'), (',', ','), ('and', 'CC'), ('fierce', 'JJ'), ('competition', 'NN'), ('.', '.'), Tree('PERSON', [('Strategy', 'NNP')]), ('plays', 'VBZ'), ('a', 'DT'), ('crucial', 'JJ'), ('role', 'NN'), (',', ','), ('with', 'IN'), ('pit', 'JJ'), ('stops', 'NNS'), (',', ','), ('tire', 'NN'), ('choices', 'NNS'), (',', ','), ('aerodynamics', 'NNS'), (',', ','), ('and', 'CC'), ('real-time', 'JJ'), ('data', 'NNS'), ('analysis', 'NN'), ('contributing', 'NN'), ('to', 'TO'), ('every', 'DT'), ('race', 'NN'), ('’', 'NNP'), ('s', 'VBZ'), ('outcome', 'NN'), ('.', '.'), ('The', 'DT'), ('roar', 'NN'), ('of', 'IN'), ('hybrid', 'JJ'), ('power', 'NN'), ('units', 'NNS'), (',', ','), ('the', 'DT'), ('complexity', 'NN'), ('of', 'IN'), ('cutting-edge', 'NN'), ('electronics', 'NNS'), (',', ','), ('and', 'CC'), ('the', 'DT'), ('artistry', 'NN'), ('of', 'IN'), ('aerodynamic', 'JJ'), ('design', 'NN'), ('make', 'VBP'), ('every', 'DT'), ('car', 'NN'), ('a', 'DT'), ('marvel', 'NN'), ('of', 'IN'), ('modern', 'JJ'), ('engineering', 'NN'), ('.', '.'), ('Beyond', 'IN'), ('the', 'DT'), ('track', 'NN'), (',', ','), Tree('GPE', [('F1', 'NNP')]), ('has', 'VBZ'), ('evolved', 'VBN'), ('into', 'IN'), ('a', 'DT'), ('massive', 'JJ'), ('global', 'JJ'), ('entertainment', 'NN'), ('industry', 'NN'), (',', ','), ('attracting', 'VBG'), ('millions', 'NNS'), ('of', 'IN'), ('fans', 'NNS'), (',', ','), ('generating', 'VBG'), ('significant', 'JJ'), ('economic', 'JJ'), ('impact', 'NN'), (',', ','), ('and', 'CC'), ('inspiring', 'VBG'), ('advancements', 'NNS'), ('in', 'IN'), ('everyday', 'JJ'), ('car', 'NN'), ('technology', 'NN'), (',', ','), ('including', 'VBG'), ('safety', 'NN'), ('systems', 'NNS'), ('and' ...

# %%
nltk.ne_chunk(tag_elements).draw()
